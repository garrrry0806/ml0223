# %% [markdown]
# <a href="https://colab.research.google.com/github/garrrry0806/ml0223/blob/main/classfication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris["data"],
                  columns=iris["feature_names"])
df["ans"] = iris["target"]
df

# %%
import numpy as np
from sklearn.model_selection import train_test_split
# [題目90, 題目10，答案90, 答案10]
x_train, x_test, y_train, y_test = train_test_split(np.array(iris["data"]),
                                                    np.array(iris["taget"]),
                                                    test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(14, 14))
plot_tree(clf, feature_names=iris["feature_names"], 
          class_names=iris["target_names"], 
          filled=True)
# Out:
# [Text(347.20000000000005, 697.62, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 135\nvalue = [42, 47, 46]\nclass = versicolor'),
#  Text(260.40000000000003, 570.78, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]\nclass = setosa'),
#  Text(434.00000000000006, 570.78, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 93\nvalue = [0, 47, 46]\nclass = versicolor'),
#  Text(347.20000000000005, 443.94, 'petal length (cm) <= 4.95\ngini = 0.174\nsamples = 52\nvalue = [0, 47, 5]\nclass = versicolor'),
#  Text(173.60000000000002, 317.1, 'petal width (cm) <= 1.65\ngini = 0.043\nsamples = 46\nvalue = [0, 45, 1]\nclass = versicolor'),
#  Text(86.80000000000001, 190.26, 'gini = 0.0\nsamples = 45\nvalue = [0, 45, 0]\nclass = versicolor'),
#  Text(260.40000000000003, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(520.8000000000001, 317.1, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
# ...
